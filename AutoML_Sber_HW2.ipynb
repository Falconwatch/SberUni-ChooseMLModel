# %% [markdown]
# <a href="https://colab.research.google.com/github/Falconwatch/SberUni-ChooseMLModel/blob/main/AutoML_Sber_HW2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# В рамках домашнего задания мы предлагаем вам поучаствовать в соревновании [Kaggle](https://www.kaggle.com/t/7e9b43b6978b4c18a58c6b60a2da2ed8). В этом соревновании вы будете прогнозировать цены на автомобили с помощью фрэймворка для AutoML [LightAutoML](https://github.com/sberbank-ai-lab/LightAutoML) by Sberbank AI Lab.
#
#
# Сначала вы получите базовое решение, а затем сможете посоревноваться между собой и другими участниками на платформе Kaggle.

# %% [markdown]
# # Установка необходимых пакетов и загрузка данных

# %%
# Google Colab has some problem with install lightautoml
# So, we need to straightforward highlight the last version of packge
# !pip install transformers # additional lib for lightautonl (optional)
# !pip install lightautoml==0.3.8b1 # lightautoml

# If you work on your own computer, you can use
#!pip install -U lightautoml

# additional
# !pip install multiprocessing

# !pip install -q vininfo

# !pip install gdown # for data loading
# !gdown 1O7n3ztzKWpY6x2vha7uuKBqksE1LjhEn # load training data
# !gdown 1gvTvn71-K6mIm_hvBWl9XKKtcqNuoRhp # load test data
# !gdown 1LyayILm9dUzifg55h3w1eAHkizGMOgxZ # load sample submission

from IPython.display import clear_output
clear_output()

# %% [markdown]
# # Импортирование необходимых библиотек

# %%
import multiprocessing as mp
import pandas as pd

from sklearn.metrics import mean_absolute_error
from lightautoml.automl.presets.tabular_presets import TabularAutoML, TabularUtilizedAutoML
from lightautoml.tasks import Task

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Загрузка данных
#
# Данные соревнования представляют собой таблицы с некоторым набором характеристик машин и целевой переменной - цена продажи.
#
# Описание признаков:
# * row_id - ID машины
# * vehicle_manufacturer - производитель машины
# * vehicle_model - модель машины
# * vehicle_category - тип кузова
# * current_mileage - текущий пробег
# * vehicle_year - год выпуска
# * vehicle_gearbox_type - тип коробки передач
# * doors_cnt - кол-во дверей
# * wheels - тип машины (праворульная/леворульная)
# * vehicle_color - цвет машины
# * vehicle_interior_color - цвет салона
# * car_vin - идентификационный номер машины
# * car_leather_interior - идентификатор, кожаный ли салон
# * deal_type - машина продается или арендуется
#
# **Целевая переменная** - final_price
#
# Загрузим обучающую и тестовую выборки и посмотрим на них.

# %%
train_data = pd.read_csv('./train_data.csv')
train_data.head()
# Out:
#    row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 0       0               TOYOTA        Aqua s            Sedan
# 1       1        MERCEDES-BENZ         C 220            Sedan
# 2       2              HYUNDAI      Veloster        Hatchback
# 3       3              HYUNDAI      Santa FE             Jeep
# 4       4               TOYOTA           CHR             Jeep
#
#    current_mileage  vehicle_year vehicle_gearbox_type doors_cnt  \
# 0           133000          2014            Automatic       4/5
# 1            24500          2010               Manual       4/5
# 2            31000          2016            Tiptronic       2/3
# 3           115459          2015            Automatic       4/5
# 4            18950          2019            Automatic       4/5
#
#                   wheels vehicle_color vehicle_interior_color  \
# 0    Right-hand drive          Silver                  Black
# 1           Left wheel         Silver                  Black
# 2           Left wheel         Silver                  Black
# 3           Left wheel           Blue                  Black
# 4           Left wheel          Black                     NaN
#
#                car_vin  car_leather_interior deal_type  final_price
# 0                  NaN                     0  For Sale       3650.0
# 1                  NaN                     0  For Sale       6800.0
# 2   KMHTC6AE3GU293912                      1  For Sale       6300.0
# 3                  NaN                     1  For Sale      14488.0
# 4   JTNKHMBX7K1030253                      1  For Sale       5000.0

# %%
test_data = pd.read_csv('./test_data.csv')
test_data.head()
# Out:
#    row_ID vehicle_manufacturer vehicle_model vehicle_category  \
# 0   35000               TOYOTA         Prius        Hatchback
# 1   35001              HYUNDAI       Elantra            Sedan
# 2   35002                LEXUS        NX 300             Jeep
# 3   35003                LEXUS       CT 200h        Hatchback
# 4   35004               TOYOTA         RAV 4             Jeep
#
#    current_mileage  vehicle_year vehicle_gearbox_type doors_cnt  \
# 0           323733          2012            Automatic       4/5
# 1           112000          2013            Tiptronic       4/5
# 2            16920          2018            Automatic       NaN
# 3           302742          2012            Automatic       4/5
# 4             1800          2002               Manual       4/5
#
#            wheels vehicle_color vehicle_interior_color              car_vin  \
# 0    Left wheel           Grey                  Black    JTDKN3DU6C5439638
# 1    Left wheel           Grey                  Black            SURATSHIA
# 2    Left wheel          Brown                     NaN   JTJYARBZ5J2104521
# 3    Left wheel          White                     NaN   JTHKD5BH4C2070945
# 4    Left wheel         Silver                  Black                   NaN
#
#    car_leather_interior deal_type
# 0                     1  For Sale
# 1                     1  For Sale
# 2                     1  For Sale
# 3                     1  For Sale
# 4                     0  For Sale

# %% [markdown]
# # FE

# %% [markdown]
# ## Чистка

# %%
def dataset_strip_strings(data):
    """Удаление лишних пробелов в строковых полях набора данных"""
    for field in data.select_dtypes(include='object'):
        data[field] = data[field].str.strip()
        data[field] = data[field].str.upper()
    return data

train_data = dataset_strip_strings(train_data)
test_data = dataset_strip_strings(test_data)

# %% [markdown]
# ## Возраст авто

# %%
def auto_age(dataset):
  dataset["auto_age"] = dataset["vehicle_year"].max() - dataset["vehicle_year"]

auto_age(train_data)
auto_age(test_data)

# %% [markdown]
# ## Полное название машины

# %%
def full_name(dataset):
  dataset['full_name'] = dataset['vehicle_manufacturer'] + dataset['vehicle_model'].fillna('')

full_name(train_data)
full_name(test_data)

# %% [markdown]
# ## Информация из VIN

# %%
from vininfo import Vin
def vin_to_dic(vin_no):
    """Преобразует VIN-номер в словарь параметров автомобиля"""
    vin_dic = {}

    try:
        vin_info = Vin(vin_no)

        vin_dic['checksum_is_ok'] = vin_info.verify_checksum()
        vin_dic['country'] = vin_info.country
        vin_dic['manufacturer'] = vin_info.manufacturer
        vin_dic['region'] = vin_info.region
        vin_dic['produce_year'] = vin_info.years[0]
        vin_dic['model_year'] = vin_info.years[1]
        vin_dic['wmi'] = vin_info.wmi      # всемирный индекс изготовителя
        vin_dic['vds'] = vin_info.vds[:-1] # технические характеристики автомобиля
        vin_dic['vis'] = vin_info.vis      # идентификационный номер автомобиля

        details = vin_info.details
        if details:
            vin_dic['details'] = True
            vin_dic['body'] = str(details.body)
            vin_dic['engine'] = str(details.engine)
            vin_dic['model'] = str(details.model)
            vin_dic['plant'] = str(details.plant)
            vin_dic['serial'] = str(details.serial)
            vin_dic['transmission'] = str(details.transmission)
        else:
            vin_dic['details'] = False

            for field in ['body', 'engine', 'model', 'plant', 'serial', 'transmission']:
                vin_dic[field] = None
    except:
        vin_dic['checksum_is_ok'] = False

    return vin_dic

# %%
vin_train_data = pd.DataFrame(list(train_data["car_vin"].apply(vin_to_dic)))
vin_test_data = pd.DataFrame(list(test_data["car_vin"].apply(vin_to_dic)))

# %%
if "wmi" not in train_data.columns:
  train_data = pd.concat([train_data,
                          vin_train_data[["checksum_is_ok", "country", "manufacturer", "region", "produce_year", "model_year", "wmi"]].copy()],
                          axis=1)

if "wmi" not in test_data.columns:
  test_data = pd.concat([test_data,
                          vin_test_data[["checksum_is_ok", "country", "manufacturer", "region", "produce_year", "model_year", "wmi"]].copy()],
                          axis=1)

# %% [markdown]
# ## Редкие цвета

# %%
car_colors = train_data["vehicle_color"].value_counts()
dict_extra_vehicle_color = {k:1 for k in car_colors[car_colors<=1000].index.values}

# %%
train_data["has_rare_color"] = train_data["vehicle_color"].map(dict_extra_vehicle_color)
train_data["has_rare_color"] .fillna(0, inplace=True)
test_data["has_rare_color"] = test_data["vehicle_color"].map(dict_extra_vehicle_color)
test_data["has_rare_color"] .fillna(0, inplace=True)

# %% [markdown]
# ## Средний пробег

# %%
train_data["millage_yearly"] = train_data["current_mileage"] / train_data["auto_age"]

# %% [markdown]
# ## Доп фичи

# %%
def create_extra_features(data):
    data['NANs_cnt'] = data.isnull().sum(axis = 1)

def create_col_with_min_freq(data, col, min_freq = 10):
    # replace rare values (less than min_freq rows) in feature by RARE_VALUE
    data[col + '_fixed'] = data[col].astype(str)
    data.loc[data[col + '_fixed'].value_counts()[data[col + '_fixed']].values < min_freq, col + '_fixed'] = "RARE_VALUE"
    data.replace({'nan': np.nan}, inplace = True)

def create_gr_feats(data):
    # create aggregation feats for numeric features based on categorical ones
    for cat_col in ['vehicle_manufacturer', 'vehicle_model', 'vehicle_category',
                   'vehicle_gearbox_type', 'doors_cnt', 'wheels', 'vehicle_color',
                   'vehicle_interior_color', 'deal_type']:
        create_col_with_min_freq(data, cat_col, 15)
        for num_col in ['current_mileage', 'vehicle_year', 'car_leather_interior']:
            for n, f in [('mean', np.mean), ('min', np.nanmin), ('max', np.nanmax)]:
                data['FIXED_' + n + '_' + num_col + '_by_' + cat_col] = data.groupby(cat_col + '_fixed')[num_col].transform(f)

    # create features with counts
    for col in ['vehicle_manufacturer', 'vehicle_model', 'vehicle_category',
               'current_mileage', 'vehicle_year', 'vehicle_gearbox_type', 'doors_cnt',
               'wheels', 'vehicle_color', 'vehicle_interior_color', 'car_vin', 'deal_type']:
        data[col + '_cnt'] = data[col].map(data[col].value_counts(dropna = False))



create_extra_features(train_data)
create_extra_features(test_data)

all_df = pd.concat([train_data, test_data]).reset_index(drop = True)
create_gr_feats(all_df)
train_data, test_data = all_df[:len(train_data)], all_df[len(train_data):]
print(train_data.shape, test_data.shape)
# Out:
# (35000, 129) (10697, 129)

# %% [markdown]
# ## Число перепродаж

# %%
sale_train_data = train_data[train_data["deal_type"]=="FOR SALE"].copy(deep=True)
sale_test_data = test_data[test_data["deal_type"]=="FOR SALE"].copy(deep=True)

# %%
sale_train_data['vin_cum_count'] = 0
sale_test_data['vin_cum_count'] = 0

vin_cumcount_train = sale_train_data[~sale_train_data.car_vin.isna()].groupby('car_vin' )['car_vin'].cumcount() + 1
sale_train_data.loc[vin_cumcount_train.index, 'vin_cum_count'] = vin_cumcount_train

vin_cumcount_test = sale_test_data[~sale_test_data.car_vin.isna()].groupby('car_vin' )['car_vin'].cumcount() + 1
sale_test_data.loc[vin_cumcount_test.index, 'vin_cum_count'] = vin_cumcount_test

# %%
train_data = train_data.merge(sale_train_data[["row_ID", "vin_cum_count"]], on = "row_ID", how="left")
train_data["vin_cum_count"].fillna(-1, inplace=True)

test_data = test_data.merge(sale_test_data[["row_ID", "vin_cum_count"]], on = "row_ID", how="left")
test_data["vin_cum_count"].fillna(-1, inplace=True)

# %% [markdown]
# # Запуск AutoML

# %%
N_THREADS = mp.cpu_count()
N_FOLDS = 5
RANDOM_STATE = 42
TEST_SIZE = 0.2 # Test size for metric check
time_out_mins = 60
TIMEOUT = 60 * time_out_mins
TARGET_NAME = 'final_price' # Target column name

# %%
nubiques = train_data.nunique().sort_values()#[:20]

# %%
nubiques[nubiques<200].index.values
# Out:
# array(['FIXED_max_car_leather_interior_by_vehicle_manufacturer',
#        'FIXED_min_car_leather_interior_by_doors_cnt',
#        'FIXED_min_current_mileage_by_wheels',
#        'FIXED_min_car_leather_interior_by_vehicle_interior_color',
#        'FIXED_max_car_leather_interior_by_vehicle_interior_color',
#        'FIXED_min_current_mileage_by_deal_type',
#        'FIXED_max_vehicle_year_by_doors_cnt',
#        'FIXED_min_car_leather_interior_by_vehicle_category',
#        'FIXED_max_current_mileage_by_deal_type',
#        'FIXED_min_current_mileage_by_vehicle_gearbox_type',
#        'FIXED_max_vehicle_year_by_deal_type',
#        'FIXED_min_car_leather_interior_by_wheels',
#        'FIXED_min_car_leather_interior_by_deal_type',
#        'FIXED_max_car_leather_interior_by_deal_type',
#        'FIXED_min_current_mileage_by_vehicle_color',
#        'FIXED_max_car_leather_interior_by_doors_cnt',
#        'FIXED_max_current_mileage_by_doors_cnt',
#        'FIXED_min_current_mileage_by_vehicle_interior_color',
#        'FIXED_min_car_leather_interior_by_vehicle_gearbox_type',
#        'FIXED_max_car_leather_interior_by_vehicle_color',
#        'FIXED_min_current_mileage_by_doors_cnt',
#        'FIXED_min_car_leather_interior_by_vehicle_color', 'deal_type',
#        'FIXED_max_car_leather_interior_by_vehicle_model',
#        'FIXED_min_car_leather_interior_by_vehicle_model',
#        'FIXED_max_current_mileage_by_wheels', 'deal_type_fixed',
#        'FIXED_mean_current_mileage_by_deal_type',
#        'FIXED_min_car_leather_interior_by_vehicle_manufacturer',
#        'deal_type_cnt', 'wheels',
#        'FIXED_max_car_leather_interior_by_vehicle_gearbox_type',
#        'FIXED_mean_vehicle_year_by_deal_type', 'checksum_is_ok',
#        'FIXED_max_car_leather_interior_by_wheels', 'car_leather_interior',
#        'FIXED_max_vehicle_year_by_vehicle_gearbox_type',
#        'FIXED_max_current_mileage_by_vehicle_gearbox_type',
#        'FIXED_max_car_leather_interior_by_vehicle_category',
#        'FIXED_mean_car_leather_interior_by_deal_type',
#        'FIXED_max_vehicle_year_by_vehicle_color',
#        'FIXED_max_vehicle_year_by_wheels',
#        'FIXED_min_vehicle_year_by_deal_type',
#        'FIXED_min_current_mileage_by_vehicle_category', 'has_rare_color',
#        'FIXED_max_vehicle_year_by_vehicle_category',
#        'FIXED_mean_car_leather_interior_by_doors_cnt',
#        'FIXED_mean_current_mileage_by_doors_cnt', 'doors_cnt_fixed',
#        'FIXED_min_vehicle_year_by_doors_cnt',
#        'FIXED_max_vehicle_year_by_vehicle_interior_color',
#        'FIXED_mean_current_mileage_by_wheels',
#        'FIXED_mean_vehicle_year_by_doors_cnt', 'wheels_cnt',
#        'FIXED_mean_vehicle_year_by_wheels',
#        'FIXED_min_vehicle_year_by_wheels', 'doors_cnt',
#        'FIXED_mean_car_leather_interior_by_wheels', 'wheels_fixed',
#        'region', 'doors_cnt_cnt', 'vehicle_gearbox_type',
#        'FIXED_min_vehicle_year_by_vehicle_gearbox_type',
#        'FIXED_max_current_mileage_by_vehicle_category',
#        'vehicle_gearbox_type_cnt',
#        'FIXED_mean_vehicle_year_by_vehicle_gearbox_type',
#        'FIXED_mean_current_mileage_by_vehicle_gearbox_type',
#        'vehicle_gearbox_type_fixed',
#        'FIXED_mean_car_leather_interior_by_vehicle_gearbox_type',
#        'FIXED_min_current_mileage_by_vehicle_manufacturer',
#        'FIXED_max_current_mileage_by_vehicle_interior_color',
#        'FIXED_max_vehicle_year_by_vehicle_manufacturer',
#        'FIXED_max_current_mileage_by_vehicle_color',
#        'FIXED_min_vehicle_year_by_vehicle_interior_color',
#        'FIXED_min_vehicle_year_by_vehicle_category', 'NANs_cnt',
#        'FIXED_mean_vehicle_year_by_vehicle_interior_color',
#        'FIXED_mean_current_mileage_by_vehicle_interior_color',
#        'vehicle_interior_color_fixed', 'vehicle_category',
#        'FIXED_mean_car_leather_interior_by_vehicle_interior_color',
#        'vehicle_interior_color', 'vehicle_interior_color_cnt',
#        'FIXED_min_vehicle_year_by_vehicle_color', 'vehicle_category_cnt',
#        'FIXED_mean_car_leather_interior_by_vehicle_category',
#        'FIXED_mean_vehicle_year_by_vehicle_category', 'model_year',
#        'vehicle_category_fixed',
#        'FIXED_mean_current_mileage_by_vehicle_category',
#        'vehicle_color_fixed', 'FIXED_mean_vehicle_year_by_vehicle_color',
#        'FIXED_mean_car_leather_interior_by_vehicle_color',
#        'vehicle_color', 'FIXED_mean_current_mileage_by_vehicle_color',
#        'vehicle_color_cnt', 'country',
#        'FIXED_max_vehicle_year_by_vehicle_model',
#        'FIXED_min_vehicle_year_by_vehicle_manufacturer', 'produce_year',
#        'FIXED_max_current_mileage_by_vehicle_manufacturer',
#        'vehicle_year_cnt', 'FIXED_min_vehicle_year_by_vehicle_model',
#        'vin_cum_count',
#        'FIXED_mean_car_leather_interior_by_vehicle_manufacturer',
#        'FIXED_mean_vehicle_year_by_vehicle_manufacturer',
#        'FIXED_mean_current_mileage_by_vehicle_manufacturer',
#        'vehicle_manufacturer_fixed', 'car_vin_cnt',
#        'vehicle_manufacturer_cnt',
#        'FIXED_min_current_mileage_by_vehicle_model', 'manufacturer',
#        'vehicle_manufacturer', 'auto_age', 'vehicle_year'], dtype=object)

# %%
task = Task('reg', loss='mae', metric = 'mae')

roles = {
        'target': TARGET_NAME,
        'id': ["row_ID"],
        'category': nubiques[nubiques<20].index.values
    }

# %%
automl = TabularUtilizedAutoML(task = task,
                       timeout = TIMEOUT,
                       cpu_limit = N_THREADS,
                       general_params = {'use_algos': [['linear_l2', 'lgb', 'lgb_tuned']]},
                       reader_params = {'n_jobs': N_THREADS, 'cv': N_FOLDS, 'random_state': RANDOM_STATE},
                      )
oof_pred = automl.fit_predict(train_data, roles = roles)
#logging.info('oof_pred:\n{}\nShape = {}'.format(oof_pred, oof_pred.shape))
# Out:
# INFO:lightautoml.addons.utilization.utilization:Start automl utilizator with listed constraints:
# INFO:lightautoml.addons.utilization.utilization:- time: 3600.00 seconds
# INFO:lightautoml.addons.utilization.utilization:- CPU: 2 cores
# INFO:lightautoml.addons.utilization.utilization:- memory: 16 GB
#
# INFO:lightautoml.addons.utilization.utilization:If one preset completes earlier, next preset configuration will be started
#
# INFO:lightautoml.addons.utilization.utilization:==================================================
# INFO:lightautoml.addons.utilization.utilization:Start 0 automl preset configuration:
# INFO:lightautoml.addons.utilization.utilization:conf_0_sel_type_0.yml, random state: {'reader_params': {'random_state': 42}, 'nn_params': {'random_state': 42}, 'general_params': {'return_all_predictions': False}}
# INFO3:lightautoml.addons.utilization.utilization:Found reader_params in kwargs, need to combine
# INFO3:lightautoml.addons.utilization.utilization:Merged variant for reader_params = {'n_jobs': 2, 'cv': 5, 'random_state': 42}
# INFO3:lightautoml.addons.utilization.utilization:Found general_params in kwargs, need to combine
# INFO3:lightautoml.addons.utilization.utilization:Merged variant for general_params = {'use_algos': [['linear_l2', 'lgb', 'lgb_tuned']], 'return_all_predictions': False}
# INFO:lightautoml.automl.presets.base:Stdout logging level is ERROR.
# INFO:lightautoml.automl.presets.base:Task: reg
#
# INFO:lightautoml.automl.presets.base:Start automl preset with listed constraints:
# INFO:lightautoml.automl.presets.base:- time: 3599.98 seconds
# INFO:lightautoml.automl.presets.base:- CPU: 2 cores
# INFO:lightautoml.automl.presets.base:- memory: 16 GB
#
# INFO:lightautoml.reader.base:Train data shape: (35000, 121)
#
# INFO3:lightautoml.reader.base:Feats was rejected during automatic roles guess: []
# INFO:lightautoml.automl.base:Layer 1 train process start. Time left 3572.27 secs
# INFO:lightautoml.ml_algo.base:Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
# DEBUG:lightautoml.ml_algo.base:Training params: {'tol': 1e-06, 'max_iter': 100, 'cs': [1e-05, 5e-05, 0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10, 50, 100, 500, 1000, 5000, 10000, 50000, 100000], 'early_stopping': 2, 'categorical_idx': [58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92, 93, 94, 95, 96, 97, 98, 99, 100, 101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150], 'embed_sizes': array([ 7,  5, 12,  3, 18,  2,  2, 13,  2,  2, 12,  5,  3,  2, 43,  3, 13,
#         2,  3, 47,  3,  3, 12,  5,  3,  3,  3,  3,  5,  4,  3, 18, 18,  3,
#         3, 18,  2,  2,  2, 18,  5, 10,  5,  3, 12,  2,  4,  2,  5,  9,  8,
#         2,  2,  3,  3,  5,  3,  3, 18,  2,  2,  5,  3,  5, 14,  5,  3, 12,
#         5,  3,  2,  8,  5,  3,  3,  3,  5,  3,  3,  3,  2,  5,  3,  2,  3,
#        10,  3,  5,  3, 12,  3, 10,  3], dtype=int32), 'data_size': 151}
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1e-05 score = -4662.600954973494
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5e-05 score = -4658.735963169643
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0001 score = -4653.8882663923
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0005 score = -4615.6136825823105
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.001 score = -4569.08667476981
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.005 score = -4287.541899309431
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.01 score = -4074.9647701939175
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.05 score = -3728.276651096889
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.1 score = -3628.743754684448
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.5 score = -3430.328344721113
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1 score = -3377.5556466761996
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5 score = -3377.555289756775
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 10 score = -3377.554854507446
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 50 score = -3377.5539052091326
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 100 score = -3335.5083851165773
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 500 score = -3317.96633492933
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1000 score = -3317.9661156899588
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5000 score = -3317.9660508858815
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 10000 score = -3317.965970199585
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 50000 score = -3317.965872626168
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 100000 score = -3317.96584727914
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1e-05 score = -6135.08644241769
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5e-05 score = -6131.248508579799
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0001 score = -6126.4425162527905
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0005 score = -6088.3315857979915
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.001 score = -6043.432598144531
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.005 score = -5768.259956194196
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.01 score = -5564.056033979144
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.05 score = -5207.738340866089
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.1 score = -5111.097287743704
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.5 score = -4941.48430481611
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1 score = -4941.48366784232
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5 score = -4886.399447789873
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 10 score = -4886.399531338283
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 50 score = -4886.399685156686
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1e-05 score = -3916.3106369280135
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5e-05 score = -3912.530658028739
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0001 score = -3907.710228515625
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0005 score = -3869.842254185268
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.001 score = -3823.90968069458
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.005 score = -3551.167875348772
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.01 score = -3347.4240736083984
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.05 score = -3030.7052322736467
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.1 score = -2947.0400818961007
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.5 score = -2794.769505969456
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1 score = -2753.927219930921
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5 score = -2753.9271242997306
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 10 score = -2753.9270522771562
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 50 score = -2753.9268414606368
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 100 score = -2713.1205103007724
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 500 score = -2713.1207272524152
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1000 score = -2713.1207272524152
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1e-05 score = -3963.5732636021207
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5e-05 score = -3959.7886004464285
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0001 score = -3954.9971427873884
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0005 score = -3917.269790248326
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.001 score = -3872.473655517578
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.005 score = -3599.0672436523437
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.01 score = -3396.551475821359
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.05 score = -3067.417540361677
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.1 score = -2969.824089857919
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.5 score = -2767.690514088222
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1 score = -2711.4067727759225
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5 score = -2648.695727157593
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 10 score = -2648.6956623687743
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 50 score = -2648.695508202689
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 100 score = -2648.695433114188
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 500 score = -2648.6953172956196
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1000 score = -2648.6952500566754
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5000 score = -2648.695003843035
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 10000 score = -2648.6949457637243
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 50000 score = -2648.6948891579764
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 100000 score = -2648.694806675502
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1e-05 score = -3731.399762137277
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5e-05 score = -3727.6111824428012
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0001 score = -3722.7903216029576
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0005 score = -3685.0520260532926
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.001 score = -3640.2796639578683
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.005 score = -3361.9970226353234
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.01 score = -3147.935899518694
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.05 score = -2793.1438587908065
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.1 score = -2696.969342254639
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.5 score = -2510.5175482548307
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1 score = -2460.9939978986467
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5 score = -2460.9937656424386
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 10 score = -2407.746955832345
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 50 score = -2407.7470917827063
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 100 score = -2407.7471882149835
# INFO:lightautoml.ml_algo.base:Fitting Lvl_0_Pipe_0_Mod_0_LinearL2 finished. score = -3194.7855135755267
# INFO:lightautoml.ml_algo.base:Lvl_0_Pipe_0_Mod_0_LinearL2 fitting and predicting completed
# INFO:lightautoml.automl.base:Time left 3265.58 secs
#
# INFO:lightautoml.ml_algo.base:Start fitting Lvl_0_Pipe_1_Mod_0_LightGBM ...
# DEBUG:lightautoml.ml_algo.base:Training params: {'task': 'train', 'learning_rate': 0.03, 'num_leaves': 32, 'feature_fraction': 0.9, 'bagging_fraction': 0.9, 'bagging_freq': 1, 'max_depth': -1, 'verbosity': -1, 'reg_alpha': 0.5, 'reg_lambda': 0.0, 'min_split_gain': 0.0, 'zero_as_missing': False, 'num_threads': 2, 'max_bin': 255, 'min_data_in_bin': 3, 'num_trees': 1200, 'early_stopping_rounds': 200, 'random_state': 42}
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's l1: 2823.06
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's l1: 2701.59
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's l1: 2678.07
# DEBUG:lightautoml.ml_algo.boost_lgbm:[400]	valid's l1: 2661.25
# DEBUG:lightautoml.ml_algo.boost_lgbm:[500]	valid's l1: 2651.52
# DEBUG:lightautoml.ml_algo.boost_lgbm:[600]	valid's l1: 2648.29
# DEBUG:lightautoml.ml_algo.boost_lgbm:[700]	valid's l1: 2643.32
# DEBUG:lightautoml.ml_algo.boost_lgbm:[800]	valid's l1: 2632.85
# DEBUG:lightautoml.ml_algo.boost_lgbm:[900]	valid's l1: 2626.8
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1000]	valid's l1: 2622.72
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1100]	valid's l1: 2620.77
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1200]	valid's l1: 2615.86
# DEBUG:lightautoml.ml_algo.boost_lgbm:Did not meet early stopping. Best iteration is:
# [1200]	valid's l1: 2615.86
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's l1: 4482.31
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's l1: 4389.67
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's l1: 4377.36
# DEBUG:lightautoml.ml_algo.boost_lgbm:[400]	valid's l1: 4366.41
# DEBUG:lightautoml.ml_algo.boost_lgbm:[500]	valid's l1: 4363.28
# DEBUG:lightautoml.ml_algo.boost_lgbm:[600]	valid's l1: 4360.82
# DEBUG:lightautoml.ml_algo.boost_lgbm:[700]	valid's l1: 4358.3
# DEBUG:lightautoml.ml_algo.boost_lgbm:[800]	valid's l1: 4352.06
# DEBUG:lightautoml.ml_algo.boost_lgbm:[900]	valid's l1: 4349.16
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1000]	valid's l1: 4348.88
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1100]	valid's l1: 4346.99
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1200]	valid's l1: 4344.28
# DEBUG:lightautoml.ml_algo.boost_lgbm:Did not meet early stopping. Best iteration is:
# [1195]	valid's l1: 4344.28
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's l1: 2086.08
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's l1: 1960.01
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's l1: 1928.53
# DEBUG:lightautoml.ml_algo.boost_lgbm:[400]	valid's l1: 1915.93
# DEBUG:lightautoml.ml_algo.boost_lgbm:[500]	valid's l1: 1893.87
# DEBUG:lightautoml.ml_algo.boost_lgbm:[600]	valid's l1: 1884.61
# DEBUG:lightautoml.ml_algo.boost_lgbm:[700]	valid's l1: 1871.03
# DEBUG:lightautoml.ml_algo.boost_lgbm:[800]	valid's l1: 1864.19
# DEBUG:lightautoml.ml_algo.boost_lgbm:[900]	valid's l1: 1858.95
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1000]	valid's l1: 1850.37
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1100]	valid's l1: 1838.91
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1200]	valid's l1: 1834.54
# DEBUG:lightautoml.ml_algo.boost_lgbm:Did not meet early stopping. Best iteration is:
# [1200]	valid's l1: 1834.54
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's l1: 2132.89
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's l1: 2020.5
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's l1: 1987.84
# DEBUG:lightautoml.ml_algo.boost_lgbm:[400]	valid's l1: 1954.26
# DEBUG:lightautoml.ml_algo.boost_lgbm:[500]	valid's l1: 1936.72
# DEBUG:lightautoml.ml_algo.boost_lgbm:[600]	valid's l1: 1931.02
# DEBUG:lightautoml.ml_algo.boost_lgbm:[700]	valid's l1: 1929.97
# DEBUG:lightautoml.ml_algo.boost_lgbm:[800]	valid's l1: 1919.99
# DEBUG:lightautoml.ml_algo.boost_lgbm:[900]	valid's l1: 1915.02
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1000]	valid's l1: 1907.5
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1100]	valid's l1: 1901.38
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1200]	valid's l1: 1892.82
# DEBUG:lightautoml.ml_algo.boost_lgbm:Did not meet early stopping. Best iteration is:
# [1200]	valid's l1: 1892.82
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_0_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's l1: 1943.27
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's l1: 1844.77
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's l1: 1823.1
# DEBUG:lightautoml.ml_algo.boost_lgbm:[400]	valid's l1: 1806.34
# DEBUG:lightautoml.ml_algo.boost_lgbm:[500]	valid's l1: 1798.41
# DEBUG:lightautoml.ml_algo.boost_lgbm:[600]	valid's l1: 1788.79
# DEBUG:lightautoml.ml_algo.boost_lgbm:[700]	valid's l1: 1771.44
# DEBUG:lightautoml.ml_algo.boost_lgbm:[800]	valid's l1: 1759.11
# DEBUG:lightautoml.ml_algo.boost_lgbm:[900]	valid's l1: 1754.68
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1000]	valid's l1: 1746.02
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1100]	valid's l1: 1742.92
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1200]	valid's l1: 1739.91
# DEBUG:lightautoml.ml_algo.boost_lgbm:Did not meet early stopping. Best iteration is:
# [1200]	valid's l1: 1739.91
# INFO:lightautoml.ml_algo.base:Fitting Lvl_0_Pipe_1_Mod_0_LightGBM finished. score = -2485.4785273611715
# INFO:lightautoml.ml_algo.base:Lvl_0_Pipe_1_Mod_0_LightGBM fitting and predicting completed
# INFO:lightautoml.ml_algo.tuning.optuna:Start hyperparameters optimization for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM ... Time budget is 300.00 secs
# WARNING:lightautoml.utils.timer:Copying TaskTimer may affect the parent PipelineTimer, so copy will create new unlimited TaskTimer
# INFO:optuna.storages._in_memory:A new study created in memory with name: no-name-2a12255c-ce74-42ca-86d4-0ed27dfa6546
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's l1: 2602.14
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's l1: 2496.3
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's l1: 2478.28
# DEBUG:lightautoml.ml_algo.boost_lgbm:[400]	valid's l1: 2468.53
# DEBUG:lightautoml.ml_algo.boost_lgbm:[500]	valid's l1: 2464.25
# DEBUG:lightautoml.ml_algo.boost_lgbm:[600]	valid's l1: 2461.9
# DEBUG:lightautoml.ml_algo.boost_lgbm:[700]	valid's l1: 2458.75
# DEBUG:lightautoml.ml_algo.boost_lgbm:[800]	valid's l1: 2458.02
# DEBUG:lightautoml.ml_algo.boost_lgbm:[900]	valid's l1: 2457.21
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1000]	valid's l1: 2457.24
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1100]	valid's l1: 2457.34
# DEBUG:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [969]	valid's l1: 2455.65
# INFO:optuna.study.study:Trial 0 finished with value: -2455.654133321268 and parameters: {'feature_fraction': 0.6872700594236812, 'num_leaves': 244, 'bagging_fraction': 0.8659969709057025, 'min_sum_hessian_in_leaf': 0.24810409748678125, 'reg_alpha': 2.5361081166471375e-07, 'reg_lambda': 2.5348407664333426e-07}. Best is trial 0 with value: -2455.654133321268.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 1 with hyperparameters {'feature_fraction': 0.6872700594236812, 'num_leaves': 244, 'bagging_fraction': 0.8659969709057025, 'min_sum_hessian_in_leaf': 0.24810409748678125, 'reg_alpha': 2.5361081166471375e-07, 'reg_lambda': 2.5348407664333426e-07} scored -2455.654133321268 in 0:01:03.251481
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's l1: 2653.39
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's l1: 2535.49
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's l1: 2520.37
# DEBUG:lightautoml.ml_algo.boost_lgbm:[400]	valid's l1: 2514.18
# DEBUG:lightautoml.ml_algo.boost_lgbm:[500]	valid's l1: 2509.35
# DEBUG:lightautoml.ml_algo.boost_lgbm:[600]	valid's l1: 2508.35
# DEBUG:lightautoml.ml_algo.boost_lgbm:[700]	valid's l1: 2505.95
# DEBUG:lightautoml.ml_algo.boost_lgbm:[800]	valid's l1: 2505.04
# DEBUG:lightautoml.ml_algo.boost_lgbm:[900]	valid's l1: 2503.77
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1000]	valid's l1: 2502.75
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1100]	valid's l1: 2500.69
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1200]	valid's l1: 2499.26
# DEBUG:lightautoml.ml_algo.boost_lgbm:Did not meet early stopping. Best iteration is:
# [1179]	valid's l1: 2498.78
# INFO:optuna.study.study:Trial 1 finished with value: -2498.7785785523292 and parameters: {'feature_fraction': 0.5290418060840998, 'num_leaves': 223, 'bagging_fraction': 0.8005575058716043, 'min_sum_hessian_in_leaf': 0.679657809075816, 'reg_alpha': 1.5320059381854043e-08, 'reg_lambda': 5.360294728728285}. Best is trial 0 with value: -2455.654133321268.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 2 with hyperparameters {'feature_fraction': 0.5290418060840998, 'num_leaves': 223, 'bagging_fraction': 0.8005575058716043, 'min_sum_hessian_in_leaf': 0.679657809075816, 'reg_alpha': 1.5320059381854043e-08, 'reg_lambda': 5.360294728728285} scored -2498.7785785523292 in 0:01:00.238285
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's l1: 2722.8
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's l1: 2603.7
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's l1: 2583.85
# DEBUG:lightautoml.ml_algo.boost_lgbm:[400]	valid's l1: 2572.39
# DEBUG:lightautoml.ml_algo.boost_lgbm:[500]	valid's l1: 2564.19
# DEBUG:lightautoml.ml_algo.boost_lgbm:[600]	valid's l1: 2557.61
# DEBUG:lightautoml.ml_algo.boost_lgbm:[700]	valid's l1: 2551.68
# DEBUG:lightautoml.ml_algo.boost_lgbm:[800]	valid's l1: 2548.96
# DEBUG:lightautoml.ml_algo.boost_lgbm:[900]	valid's l1: 2544.01
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1000]	valid's l1: 2544.4
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1100]	valid's l1: 2541.78
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1200]	valid's l1: 2540.42
# DEBUG:lightautoml.ml_algo.boost_lgbm:Did not meet early stopping. Best iteration is:
# [1198]	valid's l1: 2540.25
# INFO:optuna.study.study:Trial 2 finished with value: -2540.2537212713446 and parameters: {'feature_fraction': 0.9162213204002109, 'num_leaves': 66, 'bagging_fraction': 0.5909124836035503, 'min_sum_hessian_in_leaf': 0.00541524411940254, 'reg_alpha': 5.472429642032198e-06, 'reg_lambda': 0.00052821153945323}. Best is trial 0 with value: -2455.654133321268.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 3 with hyperparameters {'feature_fraction': 0.9162213204002109, 'num_leaves': 66, 'bagging_fraction': 0.5909124836035503, 'min_sum_hessian_in_leaf': 0.00541524411940254, 'reg_alpha': 5.472429642032198e-06, 'reg_lambda': 0.00052821153945323} scored -2540.2537212713446 in 0:00:33.268806
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's l1: 2700.01
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's l1: 2582.29
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's l1: 2570.87
# DEBUG:lightautoml.ml_algo.boost_lgbm:[400]	valid's l1: 2558.23
# DEBUG:lightautoml.ml_algo.boost_lgbm:[500]	valid's l1: 2552.74
# DEBUG:lightautoml.ml_algo.boost_lgbm:[600]	valid's l1: 2547.69
# DEBUG:lightautoml.ml_algo.boost_lgbm:[700]	valid's l1: 2544.26
# DEBUG:lightautoml.ml_algo.boost_lgbm:[800]	valid's l1: 2538.24
# DEBUG:lightautoml.ml_algo.boost_lgbm:[900]	valid's l1: 2535.98
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1000]	valid's l1: 2530.82
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1100]	valid's l1: 2530.57
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1200]	valid's l1: 2527.47
# DEBUG:lightautoml.ml_algo.boost_lgbm:Did not meet early stopping. Best iteration is:
# [1194]	valid's l1: 2527.39
# INFO:optuna.study.study:Trial 3 finished with value: -2527.3901728396245 and parameters: {'feature_fraction': 0.7159725093210578, 'num_leaves': 85, 'bagging_fraction': 0.8059264473611898, 'min_sum_hessian_in_leaf': 0.003613894271216527, 'reg_alpha': 4.258943089524393e-06, 'reg_lambda': 1.9826980964985924e-05}. Best is trial 0 with value: -2455.654133321268.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 4 with hyperparameters {'feature_fraction': 0.7159725093210578, 'num_leaves': 85, 'bagging_fraction': 0.8059264473611898, 'min_sum_hessian_in_leaf': 0.003613894271216527, 'reg_alpha': 4.258943089524393e-06, 'reg_lambda': 1.9826980964985924e-05} scored -2527.3901728396245 in 0:00:38.962620
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's l1: 2643.86
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's l1: 2541.55
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's l1: 2525.97
# DEBUG:lightautoml.ml_algo.boost_lgbm:[400]	valid's l1: 2518.05
# DEBUG:lightautoml.ml_algo.boost_lgbm:[500]	valid's l1: 2513.79
# DEBUG:lightautoml.ml_algo.boost_lgbm:[600]	valid's l1: 2510.99
# DEBUG:lightautoml.ml_algo.boost_lgbm:[700]	valid's l1: 2507.55
# DEBUG:lightautoml.ml_algo.boost_lgbm:[800]	valid's l1: 2506.85
# DEBUG:lightautoml.ml_algo.boost_lgbm:[900]	valid's l1: 2505.85
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1000]	valid's l1: 2504.88
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1100]	valid's l1: 2503.56
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1200]	valid's l1: 2504.08
# DEBUG:lightautoml.ml_algo.boost_lgbm:Did not meet early stopping. Best iteration is:
# [1128]	valid's l1: 2502.96
# INFO:optuna.study.study:Trial 4 finished with value: -2502.961099202999 and parameters: {'feature_fraction': 0.728034992108518, 'num_leaves': 204, 'bagging_fraction': 0.5998368910791798, 'min_sum_hessian_in_leaf': 0.11400863701127326, 'reg_alpha': 0.0021465011216654484, 'reg_lambda': 2.6185068507773707e-08}. Best is trial 0 with value: -2455.654133321268.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 5 with hyperparameters {'feature_fraction': 0.728034992108518, 'num_leaves': 204, 'bagging_fraction': 0.5998368910791798, 'min_sum_hessian_in_leaf': 0.11400863701127326, 'reg_alpha': 0.0021465011216654484, 'reg_lambda': 2.6185068507773707e-08} scored -2502.961099202999 in 0:00:58.445213
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's l1: 2764.33
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's l1: 2638.76
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's l1: 2607.28
# DEBUG:lightautoml.ml_algo.boost_lgbm:[400]	valid's l1: 2593.18
# DEBUG:lightautoml.ml_algo.boost_lgbm:[500]	valid's l1: 2581.6
# DEBUG:lightautoml.ml_algo.boost_lgbm:[600]	valid's l1: 2575.46
# DEBUG:lightautoml.ml_algo.boost_lgbm:[700]	valid's l1: 2566.62
# DEBUG:lightautoml.ml_algo.boost_lgbm:[800]	valid's l1: 2563.64
# DEBUG:lightautoml.ml_algo.boost_lgbm:[900]	valid's l1: 2558.84
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1000]	valid's l1: 2554.14
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1100]	valid's l1: 2551.57
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1200]	valid's l1: 2548.92
# DEBUG:lightautoml.ml_algo.boost_lgbm:Did not meet early stopping. Best iteration is:
# [1196]	valid's l1: 2548.9
# INFO:optuna.study.study:Trial 5 finished with value: -2548.895519617614 and parameters: {'feature_fraction': 0.8037724259507192, 'num_leaves': 56, 'bagging_fraction': 0.5325257964926398, 'min_sum_hessian_in_leaf': 6.245139574743075, 'reg_alpha': 4.905556676028774, 'reg_lambda': 0.18861495878553936}. Best is trial 0 with value: -2455.654133321268.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 6 with hyperparameters {'feature_fraction': 0.8037724259507192, 'num_leaves': 56, 'bagging_fraction': 0.5325257964926398, 'min_sum_hessian_in_leaf': 6.245139574743075, 'reg_alpha': 4.905556676028774, 'reg_lambda': 0.18861495878553936} scored -2548.895519617614 in 0:00:25.470382
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's l1: 2796.85
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's l1: 2678.71
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's l1: 2651.86
# DEBUG:lightautoml.ml_algo.boost_lgbm:[400]	valid's l1: 2641.96
# DEBUG:lightautoml.ml_algo.boost_lgbm:[500]	valid's l1: 2627.78
# DEBUG:lightautoml.ml_algo.boost_lgbm:[600]	valid's l1: 2619.23
# DEBUG:lightautoml.ml_algo.boost_lgbm:[700]	valid's l1: 2607.73
# DEBUG:lightautoml.ml_algo.boost_lgbm:[800]	valid's l1: 2602.81
# DEBUG:lightautoml.ml_algo.boost_lgbm:[900]	valid's l1: 2599.37
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1000]	valid's l1: 2593.98
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1100]	valid's l1: 2590.02
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1200]	valid's l1: 2584.23
# DEBUG:lightautoml.ml_algo.boost_lgbm:Did not meet early stopping. Best iteration is:
# [1199]	valid's l1: 2584.23
# INFO:optuna.study.study:Trial 6 finished with value: -2584.231181404454 and parameters: {'feature_fraction': 0.6523068845866853, 'num_leaves': 39, 'bagging_fraction': 0.8421165132560784, 'min_sum_hessian_in_leaf': 0.057624872164786026, 'reg_alpha': 1.254134495897175e-07, 'reg_lambda': 0.00028614897264046574}. Best is trial 0 with value: -2455.654133321268.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 7 with hyperparameters {'feature_fraction': 0.6523068845866853, 'num_leaves': 39, 'bagging_fraction': 0.8421165132560784, 'min_sum_hessian_in_leaf': 0.057624872164786026, 'reg_alpha': 1.254134495897175e-07, 'reg_lambda': 0.00028614897264046574} scored -2584.231181404454 in 0:00:24.485879
# INFO:lightautoml.ml_algo.tuning.optuna:Hyperparameters optimization for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM completed
# INFO2:lightautoml.ml_algo.tuning.optuna:The set of hyperparameters {'feature_fraction': 0.6872700594236812, 'num_leaves': 244, 'bagging_fraction': 0.8659969709057025, 'min_sum_hessian_in_leaf': 0.24810409748678125, 'reg_alpha': 2.5361081166471375e-07, 'reg_lambda': 2.5348407664333426e-07}
#  achieve -2455.6541 mae
# INFO:lightautoml.ml_algo.base:Start fitting Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM ...
# DEBUG:lightautoml.ml_algo.base:Training params: {'task': 'train', 'learning_rate': 0.05, 'num_leaves': 244, 'feature_fraction': 0.6872700594236812, 'bagging_fraction': 0.8659969709057025, 'bagging_freq': 1, 'max_depth': -1, 'verbosity': -1, 'reg_alpha': 2.5361081166471375e-07, 'reg_lambda': 2.5348407664333426e-07, 'min_split_gain': 0.0, 'zero_as_missing': False, 'num_threads': 2, 'max_bin': 255, 'min_data_in_bin': 3, 'num_trees': 3000, 'early_stopping_rounds': 100, 'random_state': 42, 'min_sum_hessian_in_leaf': 0.24810409748678125}
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 100 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's l1: 2519.45
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's l1: 2494.26
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's l1: 2485.44
# DEBUG:lightautoml.ml_algo.boost_lgbm:[400]	valid's l1: 2481.86
# DEBUG:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [380]	valid's l1: 2479.02
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 100 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's l1: 4315.77
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's l1: 4292.28
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's l1: 4283.73
# DEBUG:lightautoml.ml_algo.boost_lgbm:[400]	valid's l1: 4283.97
# DEBUG:lightautoml.ml_algo.boost_lgbm:[500]	valid's l1: 4283.39
# DEBUG:lightautoml.ml_algo.boost_lgbm:[600]	valid's l1: 4280.77
# DEBUG:lightautoml.ml_algo.boost_lgbm:[700]	valid's l1: 4278.93
# DEBUG:lightautoml.ml_algo.boost_lgbm:[800]	valid's l1: 4277.88
# DEBUG:lightautoml.ml_algo.boost_lgbm:[900]	valid's l1: 4277.54
# DEBUG:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [884]	valid's l1: 4277.29
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 100 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's l1: 1715.28
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's l1: 1684.99
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's l1: 1667.68
# DEBUG:lightautoml.ml_algo.boost_lgbm:[400]	valid's l1: 1664.94
# DEBUG:lightautoml.ml_algo.boost_lgbm:[500]	valid's l1: 1661.11
# DEBUG:lightautoml.ml_algo.boost_lgbm:[600]	valid's l1: 1657.31
# DEBUG:lightautoml.ml_algo.boost_lgbm:[700]	valid's l1: 1654.02
# DEBUG:lightautoml.ml_algo.boost_lgbm:[800]	valid's l1: 1651.22
# DEBUG:lightautoml.ml_algo.boost_lgbm:[900]	valid's l1: 1649.94
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1000]	valid's l1: 1648.65
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1100]	valid's l1: 1647.82
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1200]	valid's l1: 1646.48
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1300]	valid's l1: 1646.02
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1400]	valid's l1: 1644.96
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1500]	valid's l1: 1643.59
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1600]	valid's l1: 1642.92
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1700]	valid's l1: 1642.91
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1800]	valid's l1: 1642.23
# DEBUG:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1786]	valid's l1: 1641.96
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 100 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's l1: 1755.07
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's l1: 1723.62
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's l1: 1705.62
# DEBUG:lightautoml.ml_algo.boost_lgbm:[400]	valid's l1: 1694.97
# DEBUG:lightautoml.ml_algo.boost_lgbm:[500]	valid's l1: 1686.49
# DEBUG:lightautoml.ml_algo.boost_lgbm:[600]	valid's l1: 1680.88
# DEBUG:lightautoml.ml_algo.boost_lgbm:[700]	valid's l1: 1677.79
# DEBUG:lightautoml.ml_algo.boost_lgbm:[800]	valid's l1: 1674.85
# DEBUG:lightautoml.ml_algo.boost_lgbm:[900]	valid's l1: 1672.34
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1000]	valid's l1: 1670.27
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1100]	valid's l1: 1668.1
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1200]	valid's l1: 1666.58
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1300]	valid's l1: 1665.68
# DEBUG:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [1275]	valid's l1: 1665.08
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 100 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's l1: 1743.5
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's l1: 1734.42
# DEBUG:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [172]	valid's l1: 1721.93
# INFO:lightautoml.ml_algo.base:Fitting Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM finished. score = -2357.0566364062615
# INFO:lightautoml.ml_algo.base:Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM fitting and predicting completed
# INFO:lightautoml.automl.base:Time left 2566.10 secs
#
# INFO:lightautoml.automl.base:Layer 1 training completed.
#
# INFO:lightautoml.automl.blend:Blending: optimization starts with equal weights and score -2566.765725288827
# INFO:lightautoml.automl.blend:Blending: iteration 0: score = -2357.0566364062615, weights = [0. 0. 1.]
# INFO:lightautoml.automl.blend:Blending: iteration 1: score = -2357.0566364062615, weights = [0. 0. 1.]
# INFO:lightautoml.automl.blend:Blending: no score update. Terminated
#
# INFO:lightautoml.automl.presets.base:Automl preset training completed in 1033.98 seconds
#
# INFO:lightautoml.automl.presets.base:Model description:
# Final prediction for new objects (level 0) =
# 	 1.00000 * (5 averaged models Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM)
#
# INFO:lightautoml.addons.utilization.utilization:==================================================
# INFO:lightautoml.addons.utilization.utilization:Start 1 automl preset configuration:
# INFO:lightautoml.addons.utilization.utilization:conf_1_sel_type_1.yml, random state: {'reader_params': {'random_state': 43}, 'nn_params': {'random_state': 43}, 'general_params': {'return_all_predictions': False}}
# INFO3:lightautoml.addons.utilization.utilization:Found reader_params in kwargs, need to combine
# INFO3:lightautoml.addons.utilization.utilization:Merged variant for reader_params = {'n_jobs': 2, 'cv': 5, 'random_state': 43}
# INFO3:lightautoml.addons.utilization.utilization:Found general_params in kwargs, need to combine
# INFO3:lightautoml.addons.utilization.utilization:Merged variant for general_params = {'use_algos': [['linear_l2', 'lgb', 'lgb_tuned']], 'return_all_predictions': False}
# INFO:lightautoml.automl.presets.base:Stdout logging level is ERROR.
# INFO:lightautoml.automl.presets.base:Task: reg
#
# INFO:lightautoml.automl.presets.base:Start automl preset with listed constraints:
# INFO:lightautoml.automl.presets.base:- time: 2565.87 seconds
# INFO:lightautoml.automl.presets.base:- CPU: 2 cores
# INFO:lightautoml.automl.presets.base:- memory: 16 GB
#
# INFO:lightautoml.reader.base:Train data shape: (35000, 121)
#
# INFO3:lightautoml.reader.base:Feats was rejected during automatic roles guess: []
# INFO:lightautoml.automl.base:Layer 1 train process start. Time left 2549.49 secs
# INFO:lightautoml.ml_algo.base:Start fitting Lvl_0_Pipe_0_Mod_0_LinearL2 ...
# DEBUG:lightautoml.ml_algo.base:Training params: {'tol': 1e-06, 'max_iter': 100, 'cs': [1e-05, 5e-05, 0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10, 50, 100, 500, 1000, 5000, 10000, 50000, 100000], 'early_stopping': 2, 'categorical_idx': [129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186, 187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205, 206], 'embed_sizes': array([12,  3, 18,  2,  2, 13,  2,  2, 12,  5,  3,  2, 43,  3, 13,  2,  3,
#        47,  3, 12,  5,  3,  3,  3,  4,  3, 18, 18,  3,  3, 18,  2,  2,  2,
#        18,  5, 10,  5,  3, 12,  2,  2,  2,  2,  3,  3,  5,  3,  3, 18,  2,
#         2,  3,  5, 14,  5,  3, 12,  5,  2,  8,  5,  3,  3,  3,  3,  3,  3,
#         2,  5,  3,  2,  3, 10,  3,  3, 12, 10], dtype=int32), 'data_size': 207}
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 0 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1e-05 score = -4918.318288260323
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5e-05 score = -4913.645273228237
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0001 score = -4907.686618966239
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0005 score = -4861.1585535714285
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.001 score = -4806.082858642578
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.005 score = -4474.604538408552
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.01 score = -4246.65070892879
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.05 score = -3933.9533941704885
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.1 score = -3860.4207386147636
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.5 score = -3729.5511828929357
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1 score = -3729.550551094055
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5 score = -3671.078671091352
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 10 score = -3671.0785152675085
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 50 score = -3671.0783784070695
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 100 score = -3671.078206062317
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 500 score = -3671.078046991621
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1000 score = -3671.077911306109
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5000 score = -3671.0777045081004
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 10000 score = -3671.0777045081004
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 50000 score = -3671.0777045081004
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 1 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1e-05 score = -3715.432504045759
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5e-05 score = -3710.943321672712
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0001 score = -3705.2071115373883
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0005 score = -3660.725392752511
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.001 score = -3606.8204110979354
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.005 score = -3286.5340163922992
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.01 score = -3071.234505542755
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.05 score = -2765.8688499298096
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.1 score = -2690.059402608599
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.5 score = -2533.7315965494427
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1 score = -2533.731791912624
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5 score = -2436.023841444833
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 10 score = -2436.023803539821
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 50 score = -2436.023705569676
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 100 score = -2436.023705569676
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 500 score = -2436.023705569676
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 2 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1e-05 score = -4897.695849225725
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5e-05 score = -4893.127951729911
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0001 score = -4887.338665352958
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0005 score = -4841.420440429688
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.001 score = -4786.895853062221
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.005 score = -4459.720000706264
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.01 score = -4236.163492362976
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.05 score = -3925.0882016579762
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.1 score = -3846.180135935102
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.5 score = -3687.505752444676
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1 score = -3687.505752444676
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5 score = -3687.5050358963013
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 10 score = -3613.9024170924595
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 50 score = -3613.9024871150427
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 100 score = -3613.902466631208
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 3 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1e-05 score = -4999.603067208426
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5e-05 score = -4995.04510295759
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0001 score = -4989.212675641741
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0005 score = -4943.3893897181915
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.001 score = -4889.000205950056
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.005 score = -4564.259127938407
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.01 score = -4343.870562873841
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.05 score = -4021.153159338815
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.1 score = -3932.2400206691195
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.5 score = -3767.5628953465052
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1 score = -3767.5624739897594
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5 score = -3677.711809836251
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 10 score = -3677.7124777265276
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 50 score = -3677.712802712577
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 4 for Lvl_0_Pipe_0_Mod_0_LinearL2 =====
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1e-05 score = -3876.941472760882
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 5e-05 score = -3872.4905469796317
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0001 score = -3866.8638754185267
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.0005 score = -3822.3179619140624
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.001 score = -3769.8702536621095
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.005 score = -3446.4437741524835
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.01 score = -3223.9975789108275
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.05 score = -2908.468820523943
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.1 score = -2825.725196353367
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 0.5 score = -2664.4150783288137
# INFO3:lightautoml.ml_algo.torch_based.linear_model:Linear model: C = 1 score = -2664.4148304912023
# ...
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's l1: 1604.38
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's l1: 1478.71
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's l1: 1458.54
# DEBUG:lightautoml.ml_algo.boost_lgbm:[400]	valid's l1: 1445.21
# DEBUG:lightautoml.ml_algo.boost_lgbm:[500]	valid's l1: 1437.94
# DEBUG:lightautoml.ml_algo.boost_lgbm:[600]	valid's l1: 1433.19
# DEBUG:lightautoml.ml_algo.boost_lgbm:[700]	valid's l1: 1427.93
# DEBUG:lightautoml.ml_algo.boost_lgbm:[800]	valid's l1: 1424.39
# DEBUG:lightautoml.ml_algo.boost_lgbm:[900]	valid's l1: 1423.16
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1000]	valid's l1: 1421.15
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1100]	valid's l1: 1419.34
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1200]	valid's l1: 1417.67
# DEBUG:lightautoml.ml_algo.boost_lgbm:Did not meet early stopping. Best iteration is:
# [1200]	valid's l1: 1417.67
# INFO:optuna.study.study:Trial 4 finished with value: -1417.6718113254171 and parameters: {'feature_fraction': 0.728034992108518, 'num_leaves': 204, 'bagging_fraction': 0.5998368910791798, 'min_sum_hessian_in_leaf': 0.11400863701127326, 'reg_alpha': 0.0021465011216654484, 'reg_lambda': 2.6185068507773707e-08}. Best is trial 4 with value: -1417.6718113254171.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 5 with hyperparameters {'feature_fraction': 0.728034992108518, 'num_leaves': 204, 'bagging_fraction': 0.5998368910791798, 'min_sum_hessian_in_leaf': 0.11400863701127326, 'reg_alpha': 0.0021465011216654484, 'reg_lambda': 2.6185068507773707e-08} scored -1417.6718113254171 in 0:00:51.043243
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's l1: 1759.85
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's l1: 1607.89
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's l1: 1562.1
# DEBUG:lightautoml.ml_algo.boost_lgbm:[400]	valid's l1: 1538.63
# DEBUG:lightautoml.ml_algo.boost_lgbm:[500]	valid's l1: 1520.07
# DEBUG:lightautoml.ml_algo.boost_lgbm:[600]	valid's l1: 1508.41
# DEBUG:lightautoml.ml_algo.boost_lgbm:[700]	valid's l1: 1499.4
# DEBUG:lightautoml.ml_algo.boost_lgbm:[800]	valid's l1: 1491.85
# DEBUG:lightautoml.ml_algo.boost_lgbm:[900]	valid's l1: 1486.09
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1000]	valid's l1: 1481.18
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1100]	valid's l1: 1478.13
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1200]	valid's l1: 1475.45
# DEBUG:lightautoml.ml_algo.boost_lgbm:Did not meet early stopping. Best iteration is:
# [1182]	valid's l1: 1475.05
# INFO:optuna.study.study:Trial 5 finished with value: -1475.0451053300244 and parameters: {'feature_fraction': 0.8037724259507192, 'num_leaves': 56, 'bagging_fraction': 0.5325257964926398, 'min_sum_hessian_in_leaf': 6.245139574743075, 'reg_alpha': 4.905556676028774, 'reg_lambda': 0.18861495878553936}. Best is trial 4 with value: -1417.6718113254171.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 6 with hyperparameters {'feature_fraction': 0.8037724259507192, 'num_leaves': 56, 'bagging_fraction': 0.5325257964926398, 'min_sum_hessian_in_leaf': 6.245139574743075, 'reg_alpha': 4.905556676028774, 'reg_lambda': 0.18861495878553936} scored -1475.0451053300244 in 0:00:26.526234
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's l1: 1834.64
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's l1: 1684.85
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's l1: 1650.37
# DEBUG:lightautoml.ml_algo.boost_lgbm:[400]	valid's l1: 1623.71
# DEBUG:lightautoml.ml_algo.boost_lgbm:[500]	valid's l1: 1607.9
# DEBUG:lightautoml.ml_algo.boost_lgbm:[600]	valid's l1: 1594.91
# DEBUG:lightautoml.ml_algo.boost_lgbm:[700]	valid's l1: 1582.43
# DEBUG:lightautoml.ml_algo.boost_lgbm:[800]	valid's l1: 1572.32
# DEBUG:lightautoml.ml_algo.boost_lgbm:[900]	valid's l1: 1562.05
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1000]	valid's l1: 1553.51
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1100]	valid's l1: 1547.22
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1200]	valid's l1: 1539.9
# DEBUG:lightautoml.ml_algo.boost_lgbm:Did not meet early stopping. Best iteration is:
# [1200]	valid's l1: 1539.9
# INFO:optuna.study.study:Trial 6 finished with value: -1539.8976067860892 and parameters: {'feature_fraction': 0.6523068845866853, 'num_leaves': 39, 'bagging_fraction': 0.8421165132560784, 'min_sum_hessian_in_leaf': 0.057624872164786026, 'reg_alpha': 1.254134495897175e-07, 'reg_lambda': 0.00028614897264046574}. Best is trial 4 with value: -1417.6718113254171.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 7 with hyperparameters {'feature_fraction': 0.6523068845866853, 'num_leaves': 39, 'bagging_fraction': 0.8421165132560784, 'min_sum_hessian_in_leaf': 0.057624872164786026, 'reg_alpha': 1.254134495897175e-07, 'reg_lambda': 0.00028614897264046574} scored -1539.8976067860892 in 0:00:18.779832
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 200 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's l1: 1638
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's l1: 1503.79
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's l1: 1481.22
# DEBUG:lightautoml.ml_algo.boost_lgbm:[400]	valid's l1: 1471.46
# DEBUG:lightautoml.ml_algo.boost_lgbm:[500]	valid's l1: 1463.93
# DEBUG:lightautoml.ml_algo.boost_lgbm:[600]	valid's l1: 1459.27
# DEBUG:lightautoml.ml_algo.boost_lgbm:[700]	valid's l1: 1456.34
# DEBUG:lightautoml.ml_algo.boost_lgbm:[800]	valid's l1: 1454.68
# DEBUG:lightautoml.ml_algo.boost_lgbm:[900]	valid's l1: 1452.77
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1000]	valid's l1: 1450.11
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1100]	valid's l1: 1449.07
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1200]	valid's l1: 1447.17
# DEBUG:lightautoml.ml_algo.boost_lgbm:Did not meet early stopping. Best iteration is:
# [1199]	valid's l1: 1447.11
# INFO:optuna.study.study:Trial 7 finished with value: -1447.1089612281407 and parameters: {'feature_fraction': 0.5171942605576092, 'num_leaves': 234, 'bagging_fraction': 0.6293899908000085, 'min_sum_hessian_in_leaf': 0.4467752817973907, 'reg_alpha': 6.388511557344611e-06, 'reg_lambda': 0.0004793052550782129}. Best is trial 4 with value: -1417.6718113254171.
# INFO3:lightautoml.ml_algo.tuning.optuna:Trial 8 with hyperparameters {'feature_fraction': 0.5171942605576092, 'num_leaves': 234, 'bagging_fraction': 0.6293899908000085, 'min_sum_hessian_in_leaf': 0.4467752817973907, 'reg_alpha': 6.388511557344611e-06, 'reg_lambda': 0.0004793052550782129} scored -1447.1089612281407 in 0:00:47.463530
# INFO:lightautoml.ml_algo.tuning.optuna:Hyperparameters optimization for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM completed
# INFO2:lightautoml.ml_algo.tuning.optuna:The set of hyperparameters {'feature_fraction': 0.728034992108518, 'num_leaves': 204, 'bagging_fraction': 0.5998368910791798, 'min_sum_hessian_in_leaf': 0.11400863701127326, 'reg_alpha': 0.0021465011216654484, 'reg_lambda': 2.6185068507773707e-08}
#  achieve -1417.6718 mae
# INFO:lightautoml.ml_algo.base:Start fitting Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM ...
# DEBUG:lightautoml.ml_algo.base:Training params: {'task': 'train', 'learning_rate': 0.05, 'num_leaves': 204, 'feature_fraction': 0.728034992108518, 'bagging_fraction': 0.5998368910791798, 'bagging_freq': 1, 'max_depth': -1, 'verbosity': -1, 'reg_alpha': 0.0021465011216654484, 'reg_lambda': 2.6185068507773707e-08, 'min_split_gain': 0.0, 'zero_as_missing': False, 'num_threads': 2, 'max_bin': 255, 'min_data_in_bin': 3, 'num_trees': 3000, 'early_stopping_rounds': 100, 'random_state': 42, 'min_sum_hessian_in_leaf': 0.11400863701127326}
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 0 for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 100 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's l1: 1521.53
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's l1: 1479.64
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's l1: 1465.68
# DEBUG:lightautoml.ml_algo.boost_lgbm:[400]	valid's l1: 1464.71
# DEBUG:lightautoml.ml_algo.boost_lgbm:[500]	valid's l1: 1462.28
# DEBUG:lightautoml.ml_algo.boost_lgbm:[600]	valid's l1: 1458.71
# DEBUG:lightautoml.ml_algo.boost_lgbm:[700]	valid's l1: 1457.18
# DEBUG:lightautoml.ml_algo.boost_lgbm:[800]	valid's l1: 1455.46
# DEBUG:lightautoml.ml_algo.boost_lgbm:[900]	valid's l1: 1455.59
# DEBUG:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [826]	valid's l1: 1454.79
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 1 for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 100 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's l1: 1524.66
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's l1: 1469.9
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's l1: 1451.42
# DEBUG:lightautoml.ml_algo.boost_lgbm:[400]	valid's l1: 1441.2
# DEBUG:lightautoml.ml_algo.boost_lgbm:[500]	valid's l1: 1434.42
# DEBUG:lightautoml.ml_algo.boost_lgbm:[600]	valid's l1: 1429.91
# DEBUG:lightautoml.ml_algo.boost_lgbm:[700]	valid's l1: 1426.91
# DEBUG:lightautoml.ml_algo.boost_lgbm:[800]	valid's l1: 1423.23
# DEBUG:lightautoml.ml_algo.boost_lgbm:[900]	valid's l1: 1421.26
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1000]	valid's l1: 1419.09
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1100]	valid's l1: 1416.93
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1200]	valid's l1: 1415.38
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1300]	valid's l1: 1413.52
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1400]	valid's l1: 1412.31
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1500]	valid's l1: 1411.76
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1600]	valid's l1: 1411.07
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1700]	valid's l1: 1409.8
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1800]	valid's l1: 1409.15
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1900]	valid's l1: 1408.36
# DEBUG:lightautoml.ml_algo.boost_lgbm:[2000]	valid's l1: 1407.54
# DEBUG:lightautoml.ml_algo.boost_lgbm:[2100]	valid's l1: 1406.87
# DEBUG:lightautoml.ml_algo.boost_lgbm:[2200]	valid's l1: 1405.63
# DEBUG:lightautoml.ml_algo.boost_lgbm:[2300]	valid's l1: 1405.17
# DEBUG:lightautoml.ml_algo.boost_lgbm:[2400]	valid's l1: 1404.14
# DEBUG:lightautoml.ml_algo.boost_lgbm:[2500]	valid's l1: 1403.76
# DEBUG:lightautoml.ml_algo.boost_lgbm:[2600]	valid's l1: 1403.26
# DEBUG:lightautoml.ml_algo.boost_lgbm:[2700]	valid's l1: 1402.54
# DEBUG:lightautoml.ml_algo.boost_lgbm:[2800]	valid's l1: 1402.14
# DEBUG:lightautoml.ml_algo.boost_lgbm:[2900]	valid's l1: 1401.39
# DEBUG:lightautoml.ml_algo.boost_lgbm:[3000]	valid's l1: 1401.32
# DEBUG:lightautoml.ml_algo.boost_lgbm:Did not meet early stopping. Best iteration is:
# [2912]	valid's l1: 1401.22
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 2 for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 100 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's l1: 1556.32
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's l1: 1513.05
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's l1: 1497.75
# DEBUG:lightautoml.ml_algo.boost_lgbm:[400]	valid's l1: 1491.06
# DEBUG:lightautoml.ml_algo.boost_lgbm:[500]	valid's l1: 1485.8
# DEBUG:lightautoml.ml_algo.boost_lgbm:[600]	valid's l1: 1482.23
# DEBUG:lightautoml.ml_algo.boost_lgbm:[700]	valid's l1: 1478.77
# DEBUG:lightautoml.ml_algo.boost_lgbm:[800]	valid's l1: 1477.52
# DEBUG:lightautoml.ml_algo.boost_lgbm:[900]	valid's l1: 1473.89
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1000]	valid's l1: 1471.59
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1100]	valid's l1: 1470.26
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1200]	valid's l1: 1469.22
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1300]	valid's l1: 1468.2
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1400]	valid's l1: 1467.2
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1500]	valid's l1: 1465.83
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1600]	valid's l1: 1465.36
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1700]	valid's l1: 1464.52
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1800]	valid's l1: 1464.27
# DEBUG:lightautoml.ml_algo.boost_lgbm:[1900]	valid's l1: 1463.47
# DEBUG:lightautoml.ml_algo.boost_lgbm:[2000]	valid's l1: 1462.65
# DEBUG:lightautoml.ml_algo.boost_lgbm:[2100]	valid's l1: 1462.19
# DEBUG:lightautoml.ml_algo.boost_lgbm:[2200]	valid's l1: 1461.9
# DEBUG:lightautoml.ml_algo.boost_lgbm:[2300]	valid's l1: 1461.86
# DEBUG:lightautoml.ml_algo.boost_lgbm:[2400]	valid's l1: 1461.51
# DEBUG:lightautoml.ml_algo.boost_lgbm:[2500]	valid's l1: 1461.36
# DEBUG:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [2448]	valid's l1: 1461.08
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 3 for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 100 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's l1: 4211.01
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's l1: 4155.48
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's l1: 4135.83
# DEBUG:lightautoml.ml_algo.boost_lgbm:[400]	valid's l1: 4125.95
# DEBUG:lightautoml.ml_algo.boost_lgbm:[500]	valid's l1: 4120.14
# DEBUG:lightautoml.ml_algo.boost_lgbm:[600]	valid's l1: 4115.22
# DEBUG:lightautoml.ml_algo.boost_lgbm:[700]	valid's l1: 4112.53
# DEBUG:lightautoml.ml_algo.boost_lgbm:[800]	valid's l1: 4112.45
# DEBUG:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [793]	valid's l1: 4109.16
# INFO2:lightautoml.ml_algo.base:===== Start working with fold 4 for Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM =====
# INFO3:lightautoml.ml_algo.boost_lgbm:Training until validation scores don't improve for 100 rounds
# DEBUG:lightautoml.ml_algo.boost_lgbm:[100]	valid's l1: 2745.2
# DEBUG:lightautoml.ml_algo.boost_lgbm:[200]	valid's l1: 2698.61
# DEBUG:lightautoml.ml_algo.boost_lgbm:[300]	valid's l1: 2686.35
# DEBUG:lightautoml.ml_algo.boost_lgbm:[400]	valid's l1: 2676.42
# DEBUG:lightautoml.ml_algo.boost_lgbm:[500]	valid's l1: 2668.57
# DEBUG:lightautoml.ml_algo.boost_lgbm:[600]	valid's l1: 2671.9
# DEBUG:lightautoml.ml_algo.boost_lgbm:Early stopping, best iteration is:
# [527]	valid's l1: 2667.34
# INFO:lightautoml.ml_algo.base:Fitting Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM finished. score = -2218.720278644985
# INFO:lightautoml.ml_algo.base:Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM fitting and predicting completed
# INFO:lightautoml.automl.base:Time left 321.77 secs
#
# INFO:lightautoml.automl.base:Time limit exceeded in one of the tasks. AutoML will blend level 1 models.
#
# INFO:lightautoml.automl.base:Layer 1 training completed.
#
# INFO:lightautoml.automl.blend:Blending: optimization starts with equal weights and score -2385.9276020181655
# INFO:lightautoml.automl.blend:Blending: iteration 0: score = -2218.720278644985, weights = [0. 0. 1.]
# INFO:lightautoml.automl.blend:Blending: iteration 1: score = -2218.720278644985, weights = [0. 0. 1.]
# INFO:lightautoml.automl.blend:Blending: no score update. Terminated
#
# INFO:lightautoml.automl.presets.base:Automl preset training completed in 945.11 seconds
#
# INFO:lightautoml.automl.presets.base:Model description:
# Final prediction for new objects (level 0) =
# 	 1.00000 * (5 averaged models Lvl_0_Pipe_1_Mod_1_Tuned_LightGBM)
#
# INFO:lightautoml.addons.utilization.utilization:==================================================
# INFO:lightautoml.automl.blend:Blending: optimization starts with equal weights and score -2223.9352548083375
# INFO:lightautoml.automl.blend:Blending: iteration 0: score = -2198.5382246298836, weights = [0.10998189 0.2011195  0.6888986 ]
# INFO:lightautoml.automl.blend:Blending: iteration 1: score = -2198.257196167098, weights = [0.09430353 0.21757612 0.68812037]
# INFO:lightautoml.automl.blend:Blending: iteration 2: score = -2198.1769900495988, weights = [0.08776455 0.22487429 0.6873611 ]
# INFO:lightautoml.automl.blend:Blending: iteration 3: score = -2198.143203383105, weights = [0.08379069 0.22945386 0.6867555 ]
# INFO:lightautoml.automl.blend:Blending: iteration 4: score = -2198.1261145032813, weights = [0.08132093 0.23284177 0.68583727]

# %%
oof_pred.shape
# Out:
# (35000, 1)

# %% [markdown]
# ## Предсказания на тесте и качество на трейне

# %%
test_pred = automl.predict(test_data)
mean_absolute_error(train_data[TARGET_NAME].values, oof_pred.data[:, 0])
# Out:
# 2198.1261145032813

# %% [markdown]
# # Предсказание

# %%
submission = pd.read_csv('sample_submission.csv')
print(submission.shape)
submission.head()
# Out:
# (10697, 2)
#    row_ID  final_price
# 0   35000            0
# 1   35001            0
# 2   35002            0
# 3   35003            0
# 4   35004            0

# %%
test_pred.data[:, 0]
# Out:
# array([ 2826.092 ,  5610.201 ,  2437.9712, ..., 17480.807 ,  5128.2896,
#         6421.3545], dtype=float32)

# %%
sub = test_data[["row_ID"]].copy()
sub["final_price"] = test_pred.data[:, 0]

# %% [markdown]
# ## Лик

# %%
a = train_data.loc[train_data.car_vin.str.len() == 19].car_vin.value_counts()
leaks = train_data.loc[train_data.car_vin.isin(list(a[a == 1].index))]
full_df = pd.merge(leaks[['car_vin', 'final_price', 'deal_type', 'vehicle_category']],
                   test_data.loc[test_data.car_vin.str.len() == 19, ['row_ID', 'car_vin', 'deal_type', 'vehicle_category']],
                   how='inner',
                   on=['car_vin', 'deal_type', 'vehicle_category'])
for row in list(full_df.row_ID.values):
    sub.loc[sub.row_ID == row, 'final_price'] = full_df.loc[full_df.row_ID == row, 'final_price'].values

# %% [markdown]
# ## Сохраняем

# %%
from datetime import datetime
sub.to_csv('shcherbakov_ML_model_selection_HW2_{}.csv'.format(str(datetime.now())),
                        index = False)

# %% [markdown]
# Полученное решение можно загрузить на соревнование [Kaggle](https://www.kaggle.com/t/7e9b43b6978b4c18a58c6b60a2da2ed8).
#
#
# **В качестве домашнего задания мы предлагаем вам самостоятельно поэксперементировать с LightAutoML, попробовать побить текущее решение и посоревноваться между собой.**

# %% [markdown]
# # Что можно ещё попробовать?
#
# * Как бы ни был хорош AutoML, data scientist обладает несомненным преимуществом в виде своего опыта:) Например, вы можете придумать сложные признаки и/или ручной препроцессинг данных перед тем, как запускать LightAutoML. Какие идеи могут быть полезны:
#   * убрать редкие значения (outliers);
#   * посчитать различные аггрегированные значения, например, средние значения числовых признаков по разным группам или частоту возникновения категорий;
#   * поработать с VIN номером машины (см. [VIN](https://ru.wikipedia.org/wiki/%D0%98%D0%B4%D0%B5%D0%BD%D1%82%D0%B8%D1%84%D0%B8%D0%BA%D0%B0%D1%86%D0%B8%D0%BE%D0%BD%D0%BD%D1%8B%D0%B9_%D0%BD%D0%BE%D0%BC%D0%B5%D1%80_%D1%82%D1%80%D0%B0%D0%BD%D1%81%D0%BF%D0%BE%D1%80%D1%82%D0%BD%D0%BE%D0%B3%D0%BE_%D1%81%D1%80%D0%B5%D0%B4%D1%81%D1%82%D0%B2%D0%B0))
#   * выделить "особые фишки" машины (например, необычный цвет);
#   * выделить дополнительные группы в данных, например, объединить производителей по странам и/или модели по "премиальности" итд.
#
# * Рассмотреть другой набор моделей.
# * Попробовать мягче ограничивать перебор решений (увеличить TIMEOUT и/или поменять TabularAutoML на TabularUtilizedAutoML).
# * "Поиграться" с ролями.
# * Настроить пайплайн [полностью самим](https://github.com/sb-ai-lab/LightAutoML/blob/master/examples/tutorials/Tutorial_6_custom_pipeline.ipynb)) - высший пилотаж :)

# %% [markdown]
# # Баллы за эксперименты распределяются следующим образом:
# * Реализована какая-нибудь генерация признаков, которая хоть как-то улучшает базовое решение - 5 баллов;
# * За особо креативные подходы в генерации признаков - до 10 баллов дополнительно;
# * Подобраны гиперпараметры TabularAutoML - до 5 баллов;
# * Отдельно оцениваются эксперименты с TIMEOUT (в т.ч. мотивированный переход на TabularUtilizedAutoML) - 3 балла;
# ------
#
# Особые бонусы:
#
# * Реализован кастомный pipeline AutoML - до 10 баллов;
# * Топ K (K $\in$ {1, 2, 3}) на Kaggle - (4 - K) * 5 баллов.
#
#
# ![Good Luck!](https://images.fineartamerica.com/images/artworkimages/mediumlarge/2/no-prob-lama-magdalena-walulik.jpg)
